# %% [markdown]
# # Data Cleaning & Feature Engineering
# The data has no missing values, so cleaning is light. The work here is feature engineering: turning Open Date into restaurant age, dropping the high-cardinality City column, and one-hot encoding the low-cardinality categoricals.

# %% [markdown]
# ## Importing libraries

# %%
import numpy as np, pandas as pd
# %matplotlib inline
import utils

df = utils.load_data()
print('raw shape:', df.shape)
# Out:
# raw shape: (137, 43)

# %% [markdown]
# # Qualtiy Checks

# %%
print('missing values total:', df.isnull().sum().sum())
print('duplicate rows:', df.duplicated().sum())
print('City cardinality:', df['City'].nunique(), '(too granular for 137 rows -> dropped)')
# Out:
# missing values total: 0
# duplicate rows: 0
# City cardinality: 34 (too granular for 137 rows -> dropped)

# %% [markdown]
# ## Feature Engineering
#
# `create_features` parses `Open Date` → `restaurant_age_years` (from a 2010-01-01 snapshot) and drops `Id`, `Open Date`, and `City`.

# %%
fe = utils.create_features(df)
print('after feature engineering:', fe.shape)
print('new column:', 'restaurant_age_years' in fe.columns)
fe[['restaurant_age_years', 'City Group', 'Type', 'revenue']].head()
# Out:
# after feature engineering: (137, 41)
# new column: True
#    restaurant_age_years  City Group Type    revenue
# 0             10.461328  Big Cities   IL  5653753.0
# 1              1.880903  Big Cities   FC  6923131.0
# 2             -3.184120       Other   IL  2055379.0
# 3             -2.086242       Other   IL  2675511.0
# 4              0.648871       Other   IL  4316715.0

# %% [markdown]
# ## ONe hot encode categoricals
#
# `City Group` (2 levels) and `Type` (3 levels) are one-hot encoded with `drop_first=True` to avoid the dummy-variable trap.

# %%
X, y, feats = utils.preprocess_data(df)
print('feature matrix:', X.shape)
print('encoded categorical columns:', [c for c in X.columns if c.startswith(('City Group_', 'Type_'))])
print('total features:', len(feats))
# Out:
# feature matrix: (137, 41)
# encoded categorical columns: ['City Group_Other', 'Type_FC', 'Type_IL']
# total features: 41

# %% [markdown]
# ## Saving the cleaned dataset

# %%
cleaned = X.copy()
cleaned['revenue'] = y.values
cleaned.to_csv('train_cleaned.csv', index=False)
print('saved train_cleaned.csv', cleaned.shape)
print('no missing:', cleaned.isnull().sum().sum() == 0)
# Out:
# saved train_cleaned.csv (137, 42)
# no missing: True
